-- %%
UPDATE dim_drivers
SET 

     effective_from = CAST('2026-03-18' AS DATE) ,
     effective_to = CAST('2026-08-18' AS DATE),
     is_current = False

WHERE driver_id = 'b68ca58f-29e0-4f4a-996d-3ad7790b5cb3'
