-- %%
ALTER TABLE fact_stints
    ADD CONSTRAINT check_tyre_age
    CHECK (tyre_age_at_start >= 0);


ALTER TABLE fact_stints
    ADD CONSTRAINT check_lap
    CHECK(
        lap_end is NULL OR
        lap_end >= lap_start);
