-- %%
ALTER TABLE dim_teams
ALTER COLUMN team_id
    SET NOT NULL;

ALTER TABLE dim_teams
ADD CONSTRAINT team_id_pk
    PRIMARY KEY (team_id);

ALTER TABLE dim_teams
ADD CONSTRAINT team_name_nn
    CHECK (name IS NOT NULL);
