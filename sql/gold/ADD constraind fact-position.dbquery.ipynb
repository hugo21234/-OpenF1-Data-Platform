-- %%
ALTER TABLE fact_position
    ALTER COLUMN position_id
    SET NOT NULL;

ALTER TABLE fact_position
    ALTER COLUMN driver_id
    SET NOT NULL;

ALTER TABLE fact_position
    ADD CONSTRAINT pk_position_id
    PRIMARY KEY (position_id);

ALTER TABLE fact_position 
    ADD CONSTRAINT fk_driver_id_position
    FOREIGN KEY (driver_id) 
    REFERENCES dim_drivers(driver_id);
