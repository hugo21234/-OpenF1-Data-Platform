-- %%
ALTER TABLE facts_car_data
    ALTER COLUMN driver_id
    SET NOT NULL;

ALTER TABLE facts_car_data
    ALTER COLUMN car_data_id
    SET NOT NULL;

ALTER TABLE facts_car_data
    ADD CONSTRAINT fk_driver_id
    FOREIGN KEY (driver_id)
    REFERENCES dim_drivers(driver_id);

ALTER TABLE facts_car_data
    ADD CONSTRAINT pk_car_data_id
    PRIMARY KEY (car_data_id);
