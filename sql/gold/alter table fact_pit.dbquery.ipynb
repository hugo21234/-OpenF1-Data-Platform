-- %%
ALTER TABLE fact_pit
    ALTER COLUMN pit_id
    SET NOT NULL;

ALTER TABLE fact_pit
    ALTER COLUMN driver_id
    SET NOT NULL;

ALTER TABLE fact_pit
    ADD CONSTRAINT pk_fact_pit 
    PRIMARY KEY (pit_id);

ALTER TABLE fact_pit
    ADD CONSTRAINT fk_fact_pit_driver 
    FOREIGN KEY (driver_id)
    REFERENCES dim_drivers(driver_id);
