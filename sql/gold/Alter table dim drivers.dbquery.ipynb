-- %%
ALTER TABLE dim_drivers
    ALTER COLUMN team_id
    SET NOT NULL;

ALTER TABLE dim_drivers
    ALTER COLUMN driver_id
    SET NOT NULL;

ALTER TABLE dim_drivers
    ADD CONSTRAINT pk_driver_id
    PRIMARY KEY(driver_id);
--Table name: f1_plataform_data.gold.dim_teams, columns = [`team_id`: string, `team_name`: string, `
ALTER TABLE dim_drivers
    ADD CONSTRAINT fk_team_id
    FOREIGN KEY(team_id)
    REFERENCES dim_teams(team_id);
