-- %%
ALTER TABLE fact_laps
    ALTER COLUMN lap_id
    SET NOT NULL;

ALTER TABLE fact_laps
    ALTER COLUMN driver_id
    SET NOT NULL;


ALTER TABLE fact_laps
    ADD CONSTRAINT pk_lap_id
    PRIMARY KEY (lap_id);

ALTER TABLE fact_laps
    ADD CONSTRAINT fk_driver_id_laps
    FOREIGN KEY (driver_id)
    REFERENCES dim_drivers(driver_id);
